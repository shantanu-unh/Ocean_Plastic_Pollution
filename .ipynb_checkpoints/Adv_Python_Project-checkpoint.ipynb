# %% [markdown]
# <a href="https://colab.research.google.com/github/shantanu-unh/Ocean_Plastic_Pollution/blob/master/Adv_Python_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Our Group is composed of:
# Shantanu Suryawanshi
# Jafitha Johnson
# Pranay Reddy

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading Dataset in Dataframe
df = pd.read_csv('Dataset/Plastic_Consumption_Dataset.csv')
df.tail()
# Out:
#      Unnamed: 0  FID FIPS_CNTRY ISO_2DIGIT ISO_3DIGIT                NAME  \
# 301         148  149         PS         PW        PLW               Palau
# 302         149  150         RS         RU        RUS  Russian Federation
# 303         150  151         RS         RU        RUS  Russian Federation
# 304         151  152         SP         ES        ESP               Spain
# 305         152  153         SP         ES        ESP            Canarias
#
#              COUNTRYAFF CONTINENT  OBJECTID             COUNTRY  ...  \
# 301               Palau   Oceania       105               Palau  ...
# 302  Russian Federation      Asia       116  Russian Federation  ...
# 303  Russian Federation    Europe       116  Russian Federation  ...
# 304               Spain    Europe       138               Spain  ...
# 305               Spain    Africa        27            Canarias  ...
#
#      CigaretteButts  StringRingRibbon  PlasticStraps  FishingNet  \
# ...

# %%
# Removing Duplicate Values

df.drop_duplicates(subset=None, keep='first', inplace=True)
df.tail()
# Out:
#      Unnamed: 0  FID FIPS_CNTRY ISO_2DIGIT ISO_3DIGIT                NAME  \
# 148         148  149         PS         PW        PLW               Palau
# 149         149  150         RS         RU        RUS  Russian Federation
# 150         150  151         RS         RU        RUS  Russian Federation
# 151         151  152         SP         ES        ESP               Spain
# 152         152  153         SP         ES        ESP            Canarias
#
#              COUNTRYAFF CONTINENT  OBJECTID             COUNTRY  ...  \
# 148               Palau   Oceania       105               Palau  ...
# 149  Russian Federation      Asia       116  Russian Federation  ...
# 150  Russian Federation    Europe       116  Russian Federation  ...
# 151               Spain    Europe       138               Spain  ...
# 152               Spain    Africa        27            Canarias  ...
#
#      CigaretteButts  StringRingRibbon  PlasticStraps  FishingNet  \
# ...

# %%
# Checking for Nan values
df[df.isnull().any(axis=1)]
# Out:
#      Unnamed: 0  FID FIPS_CNTRY ISO_2DIGIT ISO_3DIGIT                    NAME  \
# 0             0    1         FP         PF        PYF        French Polynesia
# 54           54   55         MR         MR        MRT              Mauritania
# 69           69   70         WA        NaN        NAM                 Namibia
# 73           73   74         MA         MG        MDG              Madagascar
# 96           96   97         BK         BA        BIH  Bosnia and Herzegovina
# 103         103  104         RI         RS        SRB                  Serbia
# 111         111  112         GG         GE        GEO                 Georgia
# 130         130  131         NC         NC        NCL           New Caledonia
#
#                  COUNTRYAFF CONTINENT  OBJECTID                 COUNTRY  ...  \
# 0                    France   Oceania        50        French Polynesia  ...
# 54               Mauritania    Africa        84              Mauritania  ...
# ...

# %%
df['PlasticLighter'].median()
# Out:
# 23.0

# %%
# Filled the Nan Values with 0
# As the median values were giving incorrect values
df.fillna(0,inplace=True)

# %%
df['OBJECTID'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 148    False
# 149    False
# 150     True
# 151    False
# 152    False
# Name: OBJECTID, Length: 153, dtype: bool

# %%
df
# Out:
#      Unnamed: 0  FID FIPS_CNTRY ISO_2DIGIT ISO_3DIGIT                NAME  \
# 0             0    1         FP         PF        PYF    French Polynesia
# 1             1    2         WS         WS        WSM               Samoa
# 2             2    3         TN         TO        TON               Tonga
# 3             3    4         ES         SV        SLV         El Salvador
# 4             4    5         GT         GT        GTM           Guatemala
# ..          ...  ...        ...        ...        ...                 ...
# 148         148  149         PS         PW        PLW               Palau
# 149         149  150         RS         RU        RUS  Russian Federation
# 150         150  151         RS         RU        RUS  Russian Federation
# 151         151  152         SP         ES        ESP               Spain
# 152         152  153         SP         ES        ESP            Canarias
#
#              COUNTRYAFF      CONTINENT  OBJECTID             COUNTRY  ...  \
# ...

# %%
df.drop(index=150, inplace=True)

# %%
df['NAME'].duplicated() != False
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 147    False
# 148    False
# 149    False
# 151    False
# 152    False
# Name: NAME, Length: 152, dtype: bool

# %%
df.drop(['Unnamed: 0', 'FID', 'FIPS_CNTRY', 'ISO_2DIGIT', 'ISO_3DIGIT', 'OBJECTID', 'TotalEvents2015_2018', 'TotalLengthCleanup_m', 'AvgLengthCleanup_m', 'TotalVolunteers'], axis=1, inplace=True)

# %%
df
# Out:
#                          NAME          COUNTRYAFF      CONTINENT  \
# 0            French Polynesia              France        Oceania
# 1                       Samoa               Samoa        Oceania
# 2                       Tonga               Tonga        Oceania
# 3                 El Salvador         El Salvador  North America
# 4                   Guatemala           Guatemala  North America
# ..                        ...                 ...            ...
# 147  Northern Mariana Islands       United States        Oceania
# 148                     Palau               Palau        Oceania
# 149        Russian Federation  Russian Federation           Asia
# 151                     Spain               Spain         Europe
# 152                  Canarias               Spain         Africa
#
#                       COUNTRY  TotalDebrisltemsRecovered  \
# 0            French Polynesia                        582
# 1                       Samoa                       6889
# ...

# %%
# Getting Some insights about Dataset
df.describe()
# Out:
#        TotalDebrisltemsRecovered  TotalPlasticFoamFishingItemsRec  \
# count               1.520000e+02                     1.520000e+02
# mean                9.108433e+05                     8.401152e+05
# std                 6.557033e+06                     6.306822e+06
# min                 1.000000e+00                     0.000000e+00
# 25%                 1.436000e+03                     1.001250e+03
# 50%                 2.222800e+04                     1.856150e+04
# 75%                 1.414732e+05                     1.197615e+05
# max                 7.817442e+07                     7.566254e+07
#
#        PCT_PlasticAndFoam  PCT_Glass_Rubber_Lumber_Metal  \
# count          152.000000                     152.000000
# mean            81.201316                      18.798684
# std             14.340389                      14.340389
# min              0.000000                       0.000000
# 25%             75.300000                      10.000000
# ...

# %%
# Need to know the data type of each column
df.dtypes
# Out:
# NAME                                object
# COUNTRYAFF                          object
# CONTINENT                           object
# COUNTRY                             object
# TotalDebrisltemsRecovered            int64
# TotalPlasticFoamFishingItemsRec      int64
# PCT_PlasticAndFoam                 float64
# PCT_Glass_Rubber_Lumber_Metal      float64
# Plastic_Beverage_Bottle              int64
# Other_Plastic_Bottle                 int64
# PlasticBottleCapOrLid                int64
# Plastic_FoamFoodContainer          float64
# BucketOrCrate                        int64
# PlasticLighter                     float64
# OtherHardPlastic                     int64
# PlasticOrFoamPlatesCupsSilverwa      int64
# PlasticPersonalCareProduct           int64
# LollipopStickOrEarBud                int64
# PlasticBag                           int64
# WrapperOrLabel                       int64
# PlasticSheet                         int64
# PlasticDrinkingStraw               float64
# ...

# %%
# Plotting Total Debris Recovered from each country to its name
plt.figure(figsize=(100, 40))
# fontparams = {'font.size': 16, 'font.weight':'bold',
#               'font.family':'arial', 'font.style':'italic'}
 
# plt.rcParams.update(fontparams)
plt.plot(df['TotalDebrisltemsRecovered'], df['COUNTRY'])
plt.savefig('line.png',facecolor='w', edgecolor='w', orientation='portrait')

# %%
df
# Out:
#                          NAME          COUNTRYAFF      CONTINENT  \
# 0            French Polynesia              France        Oceania
# 1                       Samoa               Samoa        Oceania
# 2                       Tonga               Tonga        Oceania
# 3                 El Salvador         El Salvador  North America
# 4                   Guatemala           Guatemala  North America
# ..                        ...                 ...            ...
# 147  Northern Mariana Islands       United States        Oceania
# 148                     Palau               Palau        Oceania
# 149        Russian Federation  Russian Federation           Asia
# 151                     Spain               Spain         Europe
# 152                  Canarias               Spain         Africa
#
#                       COUNTRY  TotalDebrisltemsRecovered  \
# 0            French Polynesia                        582
# 1                       Samoa                       6889
# ...

# %%
# Calculating the Maximum Value from the columns
cols = df.drop(['NAME', 'COUNTRYAFF', 'CONTINENT', 'COUNTRY', 'TotalDebrisltemsRecovered', 'TotalPlasticFoamFishingItemsRec'], axis=1)
cols

max_col_value = cols.max(axis=1)#max value
# max_col_name = cols.value_counts()
df['Top_Value'] = max_col_value
# df['Top_Value_Name'] = max_col_name

# %%
df2 = cols

# %%
# Assigning Labels of Top Values i.e Names of Top Values
df['Top_Value_Names'] = cols.apply(lambda x: cols.columns[x.argmax()], axis=1)
df
# Out:
#                          NAME          COUNTRYAFF      CONTINENT  \
# 0            French Polynesia              France        Oceania
# 1                       Samoa               Samoa        Oceania
# 2                       Tonga               Tonga        Oceania
# 3                 El Salvador         El Salvador  North America
# 4                   Guatemala           Guatemala  North America
# ..                        ...                 ...            ...
# 147  Northern Mariana Islands       United States        Oceania
# 148                     Palau               Palau        Oceania
# 149        Russian Federation  Russian Federation           Asia
# 151                     Spain               Spain         Europe
# 152                  Canarias               Spain         Africa
#
#                       COUNTRY  TotalDebrisltemsRecovered  \
# 0            French Polynesia                        582
# 1                       Samoa                       6889
# ...

# %%
# Creating New Column for Top Value Percentage
df['Top_Value_Percentage'] = ((df['Top_Value']/df['TotalDebrisltemsRecovered'])*100).round(2)
df
# Out:
#                          NAME          COUNTRYAFF      CONTINENT  \
# 0            French Polynesia              France        Oceania
# 1                       Samoa               Samoa        Oceania
# 2                       Tonga               Tonga        Oceania
# 3                 El Salvador         El Salvador  North America
# 4                   Guatemala           Guatemala  North America
# ..                        ...                 ...            ...
# 147  Northern Mariana Islands       United States        Oceania
# 148                     Palau               Palau        Oceania
# 149        Russian Federation  Russian Federation           Asia
# 151                     Spain               Spain         Europe
# 152                  Canarias               Spain         Africa
#
#                       COUNTRY  TotalDebrisltemsRecovered  \
# 0            French Polynesia                        582
# 1                       Samoa                       6889
# ...

# %%
# Calculating number of outliers
a = df['Top_Value_Percentage'].values > 99
sum(a == True)
# Out:
# 17

# %%
# df2 = df2.drop(df2['Total_Count'] > df2['Top_Value'])
# Removing outliers using unary operator negate ~
df = df[~(df['Top_Value_Percentage'] > 99)]
df
# Out:
#                          NAME          COUNTRYAFF      CONTINENT  \
# 0            French Polynesia              France        Oceania
# 1                       Samoa               Samoa        Oceania
# 2                       Tonga               Tonga        Oceania
# 4                   Guatemala           Guatemala  North America
# 5                      Mexico              Mexico  North America
# ..                        ...                 ...            ...
# 147  Northern Mariana Islands       United States        Oceania
# 148                     Palau               Palau        Oceania
# 149        Russian Federation  Russian Federation           Asia
# 151                     Spain               Spain         Europe
# 152                  Canarias               Spain         Africa
#
#                       COUNTRY  TotalDebrisltemsRecovered  \
# 0            French Polynesia                        582
# 1                       Samoa                       6889
# ...

# %%
# Plotting Some Insights
# For Country vs Top_Value_Names
# plt.plot(kind='bar', figsize=(200,100))

plt.figure(figsize=(100, 40))
plt.xticks(rotation=45)
plt.bar(df['COUNTRY'], 
        df['Top_Value_Names'])

plt.savefig('a.png')

# %%
# Now displaying the result country wise
sum_of_debris = df['TotalDebrisltemsRecovered'].sum()
sum_of_debris
df_pie = pd.DataFrame()


df_pie['COUNTRY'] = df['COUNTRY']

# %%
df.groupby('COUNTRY').sum()
# Out:
#                TotalDebrisltemsRecovered  TotalPlasticFoamFishingItemsRec  \
# COUNTRY
# Algeria                             7333                             6711
# Argentina                          59930                            52717
# Aruba                                 84                               54
# Australia                         126935                           108213
# Azerbaijan                          1127                              641
# ...                                  ...                              ...
# United States                   17827180                         15408125
# Uruguay                           100415                            89771
# Vanuatu                            68801                            52920
# Venezuela                         996277                           734416
# Vietnam                            94049                            84511
#
#                PCT_PlasticAndFoam  PCT_Glass_Rubber_Lumber_Metal  \
# ...

# %%
# Pie dataframe to generate pie chart
df_pie['Percentage'] = (df['TotalDebrisltemsRecovered']/sum_of_debris)*100

# %%
df_pie['Percentage'].sum()
# Out:
# 100.0

# %%
df_pie
# Out:
#                       COUNTRY  Percentage
# 0            French Polynesia    0.000420
# 1                       Samoa    0.004976
# 2                       Tonga    0.000878
# 4                   Guatemala    0.105804
# 5                      Mexico    1.357032
# ..                        ...         ...
# 147  Northern Mariana Islands    0.069472
# 148                     Palau    0.002034
# 149        Russian Federation    0.007874
# 151                     Spain    0.209414
# 152                  Canarias    0.003946
#
# [135 rows x 2 columns]

# %%
# Plotting the pie chart
plt.pie(df_pie['Percentage'], labels=df_pie['COUNTRY'])
plt.title('Pie Chart Distribution According to Country')
plt.axis('equal')
plt.figure(figsize=(400, 100))
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.legend(labels=df_pie['COUNTRY'])
plt.show()
plt.savefig('pie1.png')
,
# Out:
# ''

# %%
df_pie.set_index("COUNTRY", inplace = True)

# %%
df_pie.loc[['Ghana', 'United States']]
# Out:
#                Percentage
# COUNTRY
# Ghana           56.464824
# United States   12.876445

# %%
# Dropping ghana in order to get insights about other countries.
df_pie = df_pie.drop('Ghana')

# %%
df_pie
# Out:
#                           Percentage
# COUNTRY
# French Polynesia            0.000420
# Samoa                       0.004976
# Tonga                       0.000878
# Guatemala                   0.105804
# Mexico                      1.357032
# ...                              ...
# Northern Mariana Islands    0.069472
# Palau                       0.002034
# Russian Federation          0.007874
# Spain                       0.209414
# Canarias                    0.003946
#
# [134 rows x 1 columns]

# %%
df_pie.index
# Out:
# Index(['French Polynesia', 'Samoa', 'Tonga', 'Guatemala', 'Mexico', 'Canada',
#        'Argentina', 'Chile', 'Ecuador', 'Peru',
#        ...
#        'South Korea', 'Guam', 'Japan', 'Marshall Islands', 'Micronesia',
#        'Northern Mariana Islands', 'Palau', 'Russian Federation', 'Spain',
#        'Canarias'],
#       dtype='object', name='COUNTRY', length=134)

# %%
# Plotting pie chart after dropping ghana
# plt.pie(df_pie['Percentage'], labels=df_pie.index)
plt.pie(df_pie['Percentage'], labels=None)
plt.title('Pie Chart Distribution According to Country without Ghana')
# plt.legend(labels=df_pie.index, loc="lower right")
plt.show()
plt.savefig('pie2.png')

# %%
# Legend
plt.pie(df_pie['Percentage'], labels=None)
plt.title('Pie Chart Distribution According to Country without Ghana')
plt.legend(labels=df_pie.index, loc="lower right")
plt.show()

# %%
df.groupby('CONTINENT').mean()
# Out:
#                TotalDebrisltemsRecovered  TotalPlasticFoamFishingItemsRec  \
# CONTINENT
# Africa                      4.007866e+06                     3.868972e+06
# Asia                        7.554408e+05                     6.732295e+05
# Australia                   1.269350e+05                     1.082130e+05
# Europe                      8.274983e+04                     6.996463e+04
# North America               9.360510e+05                     8.095962e+05
# Oceania                     3.820992e+04                     2.703567e+04
# South America               4.496200e+05                     3.547503e+05
#
#                PCT_PlasticAndFoam  PCT_Glass_Rubber_Lumber_Metal  \
# CONTINENT
# Africa                  87.385000                      12.615000
# Asia                    86.274074                      13.725926
# Australia               85.300000                      14.700000
# Europe                  79.053333                      20.946667
# ...

# %%
# Plotting results using continent.
df_cont = df.set_index('CONTINENT')

# %%
df_cont
# Out:
#                                    NAME          COUNTRYAFF  \
# CONTINENT
# Oceania                French Polynesia              France
# Oceania                           Samoa               Samoa
# Oceania                           Tonga               Tonga
# North America                 Guatemala           Guatemala
# North America                    Mexico              Mexico
# ...                                 ...                 ...
# Oceania        Northern Mariana Islands       United States
# Oceania                           Palau               Palau
# Asia                 Russian Federation  Russian Federation
# Europe                            Spain               Spain
# Africa                         Canarias               Spain
#
#                                 COUNTRY  TotalDebrisltemsRecovered  \
# CONTINENT
# Oceania                French Polynesia                        582
# Oceania                           Samoa                       6889
# ...

# %%
# Sorting the index using Continent
df_cont.sort_index(axis=0, ascending=True, inplace=False, kind='quicksort')
# Out:
#                     NAME   COUNTRYAFF    COUNTRY  TotalDebrisltemsRecovered  \
# CONTINENT
# Africa          Tanzania     Tanzania   Tanzania                     109381
# Africa           Morocco      Morocco    Morocco                       5171
# Africa           Senegal      Senegal    Senegal                       2675
# Africa             Kenya        Kenya      Kenya                     690525
# Africa            Malawi       Malawi     Malawi                     331151
# ...                  ...          ...        ...                        ...
# South America    Uruguay      Uruguay    Uruguay                     100415
# South America      Aruba        Aruba      Aruba                         84
# South America  Venezuela    Venezuela  Venezuela                     996277
# South America    Curacao  Netherlands    Curacao                      18065
# South America    Ecuador      Ecuador    Ecuador                    2598759
#
# ...

# %%
df_cont['CONTINENT'] = df['CONTINENT']

# %%
df_cont.index
# Out:
# Index(['Oceania', 'Oceania', 'Oceania', 'North America', 'North America',
#        'North America', 'South America', 'South America', 'South America',
#        'South America',
#        ...
#        'Asia', 'Oceania', 'Asia', 'Oceania', 'Oceania', 'Oceania', 'Oceania',
#        'Asia', 'Europe', 'Africa'],
#       dtype='object', name='CONTINENT', length=135)

# %%
# Sorting the index using Continent
df_cont.sort_index()
# Out:
#                     NAME   COUNTRYAFF    COUNTRY  TotalDebrisltemsRecovered  \
# CONTINENT
# Africa          Tanzania     Tanzania   Tanzania                     109381
# Africa           Morocco      Morocco    Morocco                       5171
# Africa           Senegal      Senegal    Senegal                       2675
# Africa             Kenya        Kenya      Kenya                     690525
# Africa            Malawi       Malawi     Malawi                     331151
# ...                  ...          ...        ...                        ...
# South America    Uruguay      Uruguay    Uruguay                     100415
# South America      Aruba        Aruba      Aruba                         84
# South America  Venezuela    Venezuela  Venezuela                     996277
# South America    Curacao  Netherlands    Curacao                      18065
# South America    Ecuador      Ecuador    Ecuador                    2598759
#
# ...

# %% [markdown]
# Using Mode to get the most generated plastic Continent Wise.

# %%
SA = df_cont.loc[df_cont.index == 'South America']
SA

SA['Top_Value_Names'].mode()
# Out:
# 0    Plastic_Beverage_Bottle
# dtype: object

# %%
OC = df_cont.loc[df_cont.index == 'Oceania']
OC
cnt_list = pd.DataFrame()

# %%
OC = df_cont.loc[df_cont.index == 'Oceania']
cnt_list['Oceania'] = OC['Top_Value_Names'].mode()
cnt_list
# Out:
#               Oceania
# 0  OtherPlasticDebris
# 1          PlasticBag

# %%
OC = df_cont.loc[df_cont.index == 'North America']
cnt_list['North America'] = OC['Top_Value_Names'].mode()
cnt_list
# Out:
#               Oceania            North America
# 0  OtherPlasticDebris  Plastic_Beverage_Bottle
# 1          PlasticBag                      NaN

# %%
OC = df_cont.loc[df_cont.index == 'South America']
cnt_list['South America'] = OC['Top_Value_Names'].mode()
cnt_list
# Out:
#               Oceania            North America            South America
# 0  OtherPlasticDebris  Plastic_Beverage_Bottle  Plastic_Beverage_Bottle
# 1          PlasticBag                      NaN                      NaN

# %%
OC = df_cont.loc[df_cont.index == 'Africa']
cnt_list['Africa'] = OC['Top_Value_Names'].mode()
cnt_list
# Out:
#               Oceania            North America            South America  \
# 0  OtherPlasticDebris  Plastic_Beverage_Bottle  Plastic_Beverage_Bottle
# 1          PlasticBag                      NaN                      NaN
#
#                Africa
# 0  OtherPlasticDebris
# 1                 NaN

# %%
OC = df_cont.loc[df_cont.index == 'Europe']
cnt_list['Europe'] = OC['Top_Value_Names'].mode()
cnt_list
# Out:
#               Oceania            North America            South America  \
# 0  OtherPlasticDebris  Plastic_Beverage_Bottle  Plastic_Beverage_Bottle
# 1          PlasticBag                      NaN                      NaN
#
#                Africa          Europe
# 0  OtherPlasticDebris  CigaretteButts
# 1                 NaN             NaN

# %%
OC = df_cont.loc[df_cont.index == 'Asia']
cnt_list['Asia'] = OC['Top_Value_Names'].mode()
cnt_list
# Out:
#               Oceania            North America            South America  \
# 0  OtherPlasticDebris  Plastic_Beverage_Bottle  Plastic_Beverage_Bottle
# 1          PlasticBag                      NaN                      NaN
#
#                Africa          Europe            Asia
# 0  OtherPlasticDebris  CigaretteButts  CigaretteButts
# 1                 NaN             NaN             NaN

# %%
OC = df_cont.loc[df_cont.index == 'Australia']
cnt_list['Australia'] = OC['Top_Value_Names'].mode()
cnt_list
# Out:
#               Oceania            North America            South America  \
# 0  OtherPlasticDebris  Plastic_Beverage_Bottle  Plastic_Beverage_Bottle
# 1          PlasticBag                      NaN                      NaN
#
#                Africa          Europe            Asia           Australia
# 0  OtherPlasticDebris  CigaretteButts  CigaretteButts  OtherPlasticDebris
# 1                 NaN             NaN             NaN                 NaN

# %%
cnt_list.iloc[0]
# Out:
# Oceania               OtherPlasticDebris
# North America    Plastic_Beverage_Bottle
# South America    Plastic_Beverage_Bottle
# Africa                OtherPlasticDebris
# Europe                    CigaretteButts
# Asia                      CigaretteButts
# Australia             OtherPlasticDebris
# Name: 0, dtype: object

# %%
cnt_list.columns
# Out:
# Index(['Oceania', 'North America', 'South America', 'Africa', 'Europe', 'Asia',
#        'Australia'],
#       dtype='object')

# %%
# Plotting the Top 3 Plastic waste according to each Continent
plt.xticks(rotation=45)
plt.plot(cnt_list.columns, cnt_list.iloc[0])

# %%
df_cont.index.unique()
# Out:
# Index(['Oceania', 'North America', 'South America', 'Africa', 'Europe', 'Asia',
#        'Australia'],
#       dtype='object', name='CONTINENT')

# %%
SA['Top_Value_Names'].mode()
# Out:
# 0    Plastic_Beverage_Bottle
# dtype: object

# %% [markdown]
# ## Now Logistic Regression to Predict Future Outcome

# %%
# Importing required libraries
from sklearn.linear_model import LogisticRegression
import sklearn
from sklearn.model_selection import train_test_split
LR = LogisticRegression(solver='lbfgs', random_state=555)

# %%
# Label encoding to convert object data types
for column in df.columns:
    if df[column].dtype == type(object):
        le = sklearn.preprocessing.LabelEncoder()
        df[column] = le.fit_transform(df[column])

# %%
df
# Out:
#      NAME  COUNTRYAFF  CONTINENT  COUNTRY  TotalDebrisltemsRecovered  \
# 0      40          33          5       40                        582
# 1     105          84          5      105                       6889
# 2     122         100          5      122                       1215
# 4      48          39          4       48                     146484
# 5      71          59          4       71                    1878784
# ..    ...         ...        ...      ...                        ...
# 147    82         107          5       82                      96183
# 148    86          71          5       86                       2816
# 149    96          80          1       96                      10901
# 151   115          93          3      115                     289930
# 152    21          93          0       21                       5463
#
#      TotalPlasticFoamFishingItemsRec  PCT_PlasticAndFoam  \
# 0                                399                68.6
# ...

# %%
# Splitting the dataset into train and test

X = df.drop(columns=['Top_Value_Names', 'NAME', 'COUNTRYAFF'], axis=1)
y = df['Top_Value_Names']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=555)

# %%
# Fitting and checking the accuracy of our model
scores = sklearn.model_selection.cross_val_score(LR, X_train, y_train, cv=5, scoring="accuracy")
print("Train LR Accuracy: %0.3f (+/- %0.3f) [%s]" % (scores.mean(), scores.std(), LR))
md = LR.fit(X_train, y_train)

print("Test Accuracy: %0.4f " % (sklearn.metrics.accuracy_score(LR.predict(X_test), y_test)))
print("Train Accuracy: %0.4f " % (sklearn.metrics.accuracy_score(LR.predict(X_train), y_train)))
# Out:
# Train LR Accuracy: 0.752 (+/- 0.032) [LogisticRegression(random_state=555)]
# Test Accuracy: 0.5882
# Train Accuracy: 0.8614

# %%
LR.predict(X_test)
# Out:
# array([ 9,  1, 12, 12,  5,  5,  1,  1,  3, 12, 10,  1, 10,  1, 12,  1,  5,
#         5,  5, 10,  5, 12,  1,  1, 10, 12,  1,  4, 12,  1,  9,  1,  1, 12])

# %%
print("Train Accuracy: %0.4f " % (sklearn.metrics.accuracy_score(LR.predict(X_train), y_train)))
# Out:
# Train Accuracy: 0.8614
